# %%
import numpy as np
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)

import matplotlib.pyplot as plt
import seaborn as sns

import os
import time
import re

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
df = pd.read_excel('/content/gdrive/MyDrive/cv/news_share_data.xlsx')

df.head(10)
df.shape
# Out:
#    article_id                                              title  \
# 0     7014291                 It's Time for a YouTube Competitor
# 1     7014327  The Ultimate Roundup of 2014's Biggest April F...
# 2     7014304  A Selfie and One Garish Jacket: How the Red So...
# 3     7031995    African Telecom Proposes More Diverse Emoticons
# 4     6541359  Google to Launch Improved Android Camera App, ...
# 5     7033985  Apple to Begin iPhone 6 Screen Production in M...
# 6     7014312       Apple Updates iWork for OS X, iOS and iCloud
# 7     3299703  Spare Your Facebook Friends From These 9 April...
# 8     7014271       Why Tech Takes April Fools' Day So Seriously
# 9     7008095  Atlanta Is World's Busiest Airport With 94 Mil...
#
#                                                 text published_date  \
# 0  It was reported last week that Yahoo is gettin...     2014-03-31
# 1  April Fools' marks the day when pranking goes ...     2014-04-01
# 2  The 2013 World Series champion Boston Red Sox ...     2014-04-01
# 3  Less than a week after Apple pledged to make i...     2014-04-01
# 4  Android users may soon see a series of new fea...     2014-04-01
# 5  Whispers surrounding a possible iPhone 6 relea...     2014-04-01
# 6  Apple updated its iWork suite Tuesday, adding ...     2014-04-01
# 7  Everybody's a comedian -- at least they think ...     2014-04-01
# 8  Tech journalists hate April Fools' Day. Not be...     2014-04-01
# 9  Atlanta's Hartsfield-Jackson airport remained ...     2014-04-01
#
#    unique_tokens_rate  num_hrefs  num_imgs  num_videos  average_token_length  \
# 0            0.640816          5         3           1              4.579592
# 1            0.549618          4         1           0              4.636704
# 2            0.577236          8         1           0              4.627451
# 3            0.525896          4         1           0              5.083665
# 4            0.588889          6         9           0              4.336022
# 5            0.494269          8         1           0              4.360679
# 6            0.639706          4         1           0              4.594444
# 7            0.508511         26         8           0              4.713427
# 8            0.481013          9         3           1              4.374613
# 9            0.422028         11         1           0              4.272043
#
#    num_keywords data_channel  min_avg_key  max_avg_key  avg_avg_key  \
# 0             5     Business     1459.500     4817.692     3370.415
# 1             7         Tech        0.000     3581.094     2556.367
# 2             7         Tech     2270.889     3852.800     3018.167
# 3             9         Tech        0.000     3581.094     1871.403
# 4             7        00000     3581.094     8453.451     5155.323
# 5             4     Business     3343.790     4817.692     3974.216
# 6             7    Lifestyle     2499.333     5549.418     3667.217
# 7             7         Tech     3030.861     4622.544     3761.262
# 8             8    Lifestyle        0.000     6813.466     3745.055
# 9             5     Business     3343.790     5585.617     4111.006
#
#    href_avg_shares  global_subjectivity  global_sentiment_polarity  \
# 0         1833.333             0.403762                   0.038762
# 1         8500.000             0.410707                   0.180934
# 2         2076.333             0.397545                   0.044864
# 3         2200.000             0.491578                   0.157620
# 4          805.000             0.628535                   0.078497
# 5        31625.000             0.567866                   0.098980
# 6         4800.000             0.347222                   0.186111
# 7         3700.000             0.484539                   0.134520
# 8        11800.000             0.533060                   0.186324
# 9         2600.000             0.502861                   0.121931
#
#    global_rate_positive_words  global_rate_negative_words  title_subjectivity  \
# 0                    0.036735                    0.024490            0.250000
# 1                    0.044944                    0.003745            0.000000
# 2                    0.035294                    0.019608            0.000000
# 3                    0.047809                    0.011952            0.000000
# 4                    0.053763                    0.034946            0.000000
# 5                    0.038190                    0.024045            0.666667
# 6                    0.033333                    0.005556            0.000000
# 7                    0.050100                    0.026052            0.400000
# 8                    0.046440                    0.021672            0.066667
# 9                    0.043011                    0.018280            0.357143
#
#    title_sentiment_polarity  shares
# 0                  0.250000    1600
# 1                  0.000000    1500
# 2                  0.000000    1400
# 3                  0.000000    1300
# 4                  0.000000    3000
# 5                 -0.333330    1600
# 6                  0.000000    1300
# 7                 -0.150000    2000
# 8                  0.033333    2100
# 9                  0.000000    1100

# %%
summary_statistics = df.describe()

summary_statistics
# Out:
#          article_id  unique_tokens_rate    num_hrefs     num_imgs  \
# count  1.003000e+03         1003.000000  1003.000000  1003.000000
# mean   6.915159e+06            0.526890    11.720837     5.188435
# std    4.823885e+05            0.118793    15.181597     8.495002
# min    2.195051e+06            0.000000     0.000000     0.000000
# 25%    7.006102e+06            0.466751     4.000000     1.000000
# 50%    7.013065e+06            0.533118     8.000000     2.000000
# 75%    7.027570e+06            0.596615    14.000000     7.000000
# max    7.041291e+06            0.867925   162.000000    84.000000
#
#         num_videos  average_token_length  num_keywords  min_avg_key  \
# count  1003.000000           1003.000000   1003.000000  1003.000000
# mean      1.215354              4.603757      7.206381  1131.437972
# std       4.079730              0.701756      1.856713  1181.134621
# min       0.000000              0.000000      2.000000     0.000000
# 25%       0.000000              4.490363      6.000000     0.000000
# 50%       0.000000              4.685484      7.000000   984.066700
# 75%       1.000000              4.855388      9.000000  2116.714500
# max      51.000000              7.218430     10.000000  3613.040000
#
#          max_avg_key   avg_avg_key  href_avg_shares  global_subjectivity  \
# count    1003.000000   1003.000000      1003.000000          1003.000000
# mean     6463.258234   3359.478830     13518.302031             0.446724
# std      7455.421154   1467.674637     51499.106509             0.109167
# min      3568.870000   1360.101000         0.000000             0.000000
# 25%      3613.040000   2533.297000      1300.000000             0.395575
# 50%      4635.807000   3004.755000      2766.667000             0.455990
# 75%      6561.910000   3809.005000      7341.000000             0.509508
# max    102200.000000  17604.270000    663600.000000             0.875000
#
#        global_sentiment_polarity  global_rate_positive_words  \
# count                1003.000000                 1003.000000
# mean                    0.106187                    0.038169
# std                     0.092496                    0.015673
# min                    -0.300000                    0.000000
# 25%                     0.051911                    0.028655
# 50%                     0.102579                    0.037325
# 75%                     0.163183                    0.046922
# max                     0.489623                    0.120805
#
#        global_rate_negative_words  title_subjectivity  \
# count                 1003.000000         1003.000000
# mean                     0.017772            0.292537
# std                      0.010557            0.325227
# min                      0.000000            0.000000
# 25%                      0.011224            0.000000
# 50%                      0.016266            0.200000
# 75%                      0.022597            0.500000
# max                      0.103030            1.000000
#
#        title_sentiment_polarity         shares
# count               1003.000000    1003.000000
# mean                   0.057536    4247.304088
# std                    0.266609   22609.634435
# min                   -1.000000      58.000000
# 25%                    0.000000    1000.000000
# 50%                    0.000000    1600.000000
# 75%                    0.150000    3100.000000
# max                    1.000000  663600.000000

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# article_id                    0
# title                         0
# text                          0
# published_date                0
# unique_tokens_rate            0
# num_hrefs                     0
# num_imgs                      0
# num_videos                    0
# average_token_length          0
# num_keywords                  0
# data_channel                  0
# min_avg_key                   0
# max_avg_key                   0
# avg_avg_key                   0
# href_avg_shares               0
# global_subjectivity           0
# global_sentiment_polarity     0
# global_rate_positive_words    0
# global_rate_negative_words    0
# title_subjectivity            0
# title_sentiment_polarity      0
# shares                        0
# dtype: int64

# %%
correlation_matrix = df.corr()
correlation_matrix
# Out:
# <ipython-input-19-f471181e404f>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   correlation_matrix = df.corr()
#                             article_id  unique_tokens_rate  num_hrefs  \
# article_id                    1.000000            0.044316  -0.022245
# unique_tokens_rate            0.044316            1.000000  -0.107830
# num_hrefs                    -0.022245           -0.107830   1.000000
# num_imgs                     -0.017718           -0.215217   0.308931
# num_videos                    0.030276            0.085648   0.195974
# average_token_length          0.003438            0.577242   0.200420
# num_keywords                  0.005834           -0.087271   0.095339
# min_avg_key                  -0.026784            0.036999   0.099490
# max_avg_key                   0.018693            0.041947   0.065795
# avg_avg_key                   0.024149            0.112696   0.179366
# href_avg_shares               0.014067           -0.005914   0.017652
# global_subjectivity          -0.027058            0.437065   0.141574
# global_sentiment_polarity    -0.060894            0.076683   0.014169
# global_rate_positive_words   -0.058031            0.193362  -0.009477
# global_rate_negative_words    0.049794            0.185404   0.054581
# title_subjectivity           -0.028862           -0.032135   0.077283
# title_sentiment_polarity     -0.003529           -0.027175   0.000053
# shares                        0.012057           -0.060329   0.077955
#
#                             num_imgs  num_videos  average_token_length  \
# article_id                 -0.017718    0.030276              0.003438
# unique_tokens_rate         -0.215217    0.085648              0.577242
# num_hrefs                   0.308931    0.195974              0.200420
# num_imgs                    1.000000   -0.041545             -0.027793
# num_videos                 -0.041545    1.000000              0.035405
# average_token_length       -0.027793    0.035405              1.000000
# num_keywords                0.101744   -0.012461              0.007070
# min_avg_key                 0.068255    0.114448             -0.001002
# max_avg_key                 0.073388    0.093452             -0.003079
# avg_avg_key                 0.165019    0.184691              0.006593
# href_avg_shares            -0.045221   -0.011952              0.051989
# global_subjectivity         0.037593    0.100673              0.470466
# global_sentiment_polarity   0.028084   -0.042884              0.111966
# global_rate_positive_words -0.044526    0.018137              0.236963
# global_rate_negative_words  0.005820    0.137706              0.180000
# title_subjectivity          0.023777    0.067764             -0.042569
# title_sentiment_polarity    0.012981    0.026793              0.000539
# shares                     -0.008089   -0.001938             -0.000077
#
#                             num_keywords  min_avg_key  max_avg_key  \
# article_id                      0.005834    -0.026784     0.018693
# unique_tokens_rate             -0.087271     0.036999     0.041947
# num_hrefs                       0.095339     0.099490     0.065795
# num_imgs                        0.101744     0.068255     0.073388
# num_videos                     -0.012461     0.114448     0.093452
# average_token_length            0.007070    -0.001002    -0.003079
# num_keywords                    1.000000    -0.256870     0.110168
# min_avg_key                    -0.256870     1.000000     0.111037
# max_avg_key                     0.110168     0.111037     1.000000
# avg_avg_key                     0.059784     0.432896     0.848766
# href_avg_shares                -0.041685     0.096177     0.096850
# global_subjectivity             0.054133     0.076723     0.083381
# global_sentiment_polarity       0.019309    -0.050810     0.051256
# global_rate_positive_words      0.025759     0.010977     0.032843
# global_rate_negative_words      0.028994     0.097446     0.004661
# title_subjectivity              0.010772     0.024798     0.067228
# title_sentiment_polarity        0.001226    -0.054762     0.073013
# shares                          0.044015    -0.010040    -0.003706
#
#                             avg_avg_key  href_avg_shares  global_subjectivity  \
# article_id                     0.024149         0.014067            -0.027058
# unique_tokens_rate             0.112696        -0.005914             0.437065
# num_hrefs                      0.179366         0.017652             0.141574
# num_imgs                       0.165019        -0.045221             0.037593
# num_videos                     0.184691        -0.011952             0.100673
# average_token_length           0.006593         0.051989             0.470466
# num_keywords                   0.059784        -0.041685             0.054133
# min_avg_key                    0.432896         0.096177             0.076723
# max_avg_key                    0.848766         0.096850             0.083381
# avg_avg_key                    1.000000         0.124246             0.222322
# href_avg_shares                0.124246         1.000000             0.081958
# global_subjectivity            0.222322         0.081958             1.000000
# global_sentiment_polarity      0.027258        -0.026649             0.251761
# global_rate_positive_words     0.079059        -0.002080             0.442730
# global_rate_negative_words     0.115398         0.028331             0.259632
# title_subjectivity             0.101809        -0.022486             0.127591
# title_sentiment_polarity       0.019219        -0.008034            -0.019509
# shares                         0.015171         0.018945             0.022757
#
#                             global_sentiment_polarity  \
# article_id                                  -0.060894
# unique_tokens_rate                           0.076683
# num_hrefs                                    0.014169
# num_imgs                                     0.028084
# num_videos                                  -0.042884
# average_token_length                         0.111966
# num_keywords                                 0.019309
# min_avg_key                                 -0.050810
# max_avg_key                                  0.051256
# avg_avg_key                                  0.027258
# href_avg_shares                             -0.026649
# global_subjectivity                          0.251761
# global_sentiment_polarity                    1.000000
# global_rate_positive_words                   0.600684
# global_rate_negative_words                  -0.520060
# title_subjectivity                          -0.003362
# title_sentiment_polarity                     0.283686
# shares                                      -0.025610
#
#                             global_rate_positive_words  \
# article_id                                   -0.058031
# unique_tokens_rate                            0.193362
# num_hrefs                                    -0.009477
# num_imgs                                     -0.044526
# num_videos                                    0.018137
# average_token_length                          0.236963
# num_keywords                                  0.025759
# min_avg_key                                   0.010977
# max_avg_key                                   0.032843
# avg_avg_key                                   0.079059
# href_avg_shares                              -0.002080
# global_subjectivity                           0.442730
# global_sentiment_polarity                     0.600684
# global_rate_positive_words                    1.000000
# global_rate_negative_words                    0.037302
# title_subjectivity                            0.067091
# title_sentiment_polarity                      0.154630
# shares                                       -0.019037
#
#                             global_rate_negative_words  title_subjectivity  \
# article_id                                    0.049794           -0.028862
# unique_tokens_rate                            0.185404           -0.032135
# num_hrefs                                     0.054581            0.077283
# num_imgs                                      0.005820            0.023777
# num_videos                                    0.137706            0.067764
# average_token_length                          0.180000           -0.042569
# num_keywords                                  0.028994            0.010772
# min_avg_key                                   0.097446            0.024798
# max_avg_key                                   0.004661            0.067228
# avg_avg_key                                   0.115398            0.101809
# href_avg_shares                               0.028331           -0.022486
# global_subjectivity                           0.259632            0.127591
# global_sentiment_polarity                    -0.520060           -0.003362
# global_rate_positive_words                    0.037302            0.067091
# global_rate_negative_words                    1.000000            0.071422
# title_subjectivity                            0.071422            1.000000
# title_sentiment_polarity                     -0.217760            0.156565
# shares                                        0.004837            0.021480
#
#                             title_sentiment_polarity    shares
# article_id                                 -0.003529  0.012057
# unique_tokens_rate                         -0.027175 -0.060329
# num_hrefs                                   0.000053  0.077955
# num_imgs                                    0.012981 -0.008089
# num_videos                                  0.026793 -0.001938
# average_token_length                        0.000539 -0.000077
# num_keywords                                0.001226  0.044015
# min_avg_key                                -0.054762 -0.010040
# max_avg_key                                 0.073013 -0.003706
# avg_avg_key                                 0.019219  0.015171
# href_avg_shares                            -0.008034  0.018945
# global_subjectivity                        -0.019509  0.022757
# global_sentiment_polarity                   0.283686 -0.025610
# global_rate_positive_words                  0.154630 -0.019037
# global_rate_negative_words                 -0.217760  0.004837
# title_subjectivity                          0.156565  0.021480
# title_sentiment_polarity                    1.000000  0.024815
# shares                                      0.024815  1.000000

# %%
import matplotlib.pyplot as plt
import seaborn as sns

features_to_plot = ['shares', 'unique_tokens_rate', 'num_hrefs', 'num_imgs', 'num_videos']

# Plotting distributions
fig, axes = plt.subplots(len(features_to_plot), figsize=(8, 20))
for i, feature in enumerate(features_to_plot):
    sns.histplot(df[feature], bins=50, ax=axes[i])
    axes[i].set_title(f'Distribution of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Frequency')
plt.tight_layout()

# %%
import matplotlib.pyplot as plt
import pandas as pd

df['published_date'] = pd.to_datetime(df['published_date'])

# Group by published_date and calculate mean of shares
trend_data = df.groupby(df['published_date'].dt.date).mean()

# Plotting
plt.figure(figsize=(12, 6))
plt.plot(trend_data['shares'])
plt.title('Trend of Average Shares Over Time')
plt.xlabel('Date')
plt.ylabel('Average Shares')
plt.xticks(rotation=45)
plt.show()
# Out:
# <ipython-input-25-c28e02a3a622>:8: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   trend_data = df.groupby(df['published_date'].dt.date).mean()

# %%
# Scatter plot of global subjectivity vs shares
plt.figure(figsize=(10, 6))
plt.scatter(df['global_subjectivity'], df['shares'])
plt.title('Global Subjectivity vs Shares')
plt.xlabel('Global Subjectivity')
plt.ylabel('Shares')
plt.show()

# Scatter plot of global sentiment polarity vs shares
plt.figure(figsize=(10, 6))
plt.scatter(df['global_sentiment_polarity'], df['shares'])
plt.title('Global Sentiment Polarity vs Shares')
plt.xlabel('Global Sentiment Polarity')
plt.ylabel('Shares')
plt.show()

# %%
# Correlation matrix for selected features
selected_features = ['num_hrefs', 'num_imgs', 'num_videos', 'average_token_length',
                     'global_subjectivity', 'global_sentiment_polarity', 'shares']
correlation_matrix = df[selected_features].corr()

# Heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap for Selected Features')
plt.show()
